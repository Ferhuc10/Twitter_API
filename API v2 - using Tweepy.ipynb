# %%
import tweepy 
import pandas as pd

### For more info on Tweepy: Check out the documentation here: https://docs.tweepy.org/

# %%
Access_Token = "203369537-PbKVtncLxrbsANsFo58RzDTFJIRCXPG2fjpvQVZq"
Access_Token_Secret = "bC9wPltcrZH9xpEqYjYTUG0yiPohATGPBqpx1LXz8ufy3"

API_Key = "GanokZfGsXhowywYghiCk12FU"
API_Key_Secret = "HjdKN4B74bx7TQ4ALHgEBo79kOTg0nwcJzGOHSJjQlrywC3ubK"
Bearer_Token = "AAAAAAAAAAAAAAAAAAAAANiVewEAAAAAjqRkXmbL7msbZDyzpqkaEuM607Y%3D7BpCbmQBduWJ6nOns5qtwExeeGF4LCslTmjZhpuIHjn0d9UD7Y"
user_id = 2244994945

# %%
#Auth 
client = tweepy.Client(bearer_token = Bearer_Token)
query = 'covid -is:retweet'
response = client.search_recent_tweets(query = query, max_results = 100)
response
# Out:
# Response(data=[<Tweet id=1552446569047359489 text='COVID-19. Sobre vacunas. https://t.co/KbKLpID9Qf'>, <Tweet id=1552446567873150977 text='@Jim_Jordan Because they can\'t drive fear of Monkeypox  and Covid to scare people into locking down so they can roll out ,what Joe Biden called" the vast network of voter fraud"!'>, <Tweet id=1552446567642464256 text="@fedesiino @AngeloCapparel9 @evamarghe Signora, ripeto il Rapporto Debito/PIL é cresciuto durante l'anno 2019; non eravamo  in piena pandemia; i primi casi Covid accertati risalgono a fine febbraio 2020. Come dice open polis c'è stata diminuzione durante il 2020 fino a fine 2021. Quale sia la situazione ora non lo so. https://t.co/oWqunBD3Fl">, <Tweet id=1552446565515935745 text='I let my dyed blonde hair go natural during Covid. Been 2 years + and I love the freedom. The look on my face is because I’ve had one jumbo margarita and two tall draft beers! 😊 https://t.co/j413o6AU4b'>, <Tweet id=1552446563838218240 text='@MrAlonzoFont @T
# ...

# %%
for tweet in response.data:
    print(tweet.id)
# Out:
# 1552446569047359489
# 1552446567873150977
# 1552446567642464256
# 1552446565515935745
# 1552446563838218240
# 1552446562315427841
# 1552446559228665856
# 1552446558263820288
# 1552446556204580864
# 1552446554258153473
# 1552446550621966336
# 1552446548176519168
# 1552446543885930501
# 1552446540350107648
# 1552446538819186688
# 1552446537804185603
# 1552446535174340608
# 1552446528731635712
# 1552446528308248576
# 1552446524046848001
# 1552446521752408064
# 1552446520762531843
# 1552446520246796288
# 1552446517327597568
# 1552446514076995584
# 1552446502580404224
# 1552446501351493632
# 1552446499338207232
# 1552446499208200192
# 1552446497823887366
# 1552446496066670593
# 1552446494955151360
# 1552446494434893827
# 1552446494304780291
# 1552446494091145216
# 1552446487606460418
# 1552446484897202176
# 1552446483009617920
# 1552446482263216128
# 1552446478114766850
# 1552446474088488963
# 1552446466203197443
# 1552446466115125249
# 1552446465083318272
# 1552446464919584770
# ...

# %%
response = client.search_recent_tweets(query = query, max_results = 100, tweet_fields = ['created_at', 'lang'])
response
# Out:
# Response(data=[<Tweet id=1552446572662853632 text="Joe Biden didn't have Covid 19! After his big F.U.C.K UP trip to Israel, Saudi Arabia, etc &amp; looking like a complete loser &amp; idiot to the whole world. The Dems wanted to hide Joe Biden from us, Citizens for 2 wks, before he screw up again!">, <Tweet id=1552446572382027776 text='@JoyceS763 And again. Can do this all day.\n\nhttps://t.co/U0hM9efkz0'>, <Tweet id=1552446569047359489 text='COVID-19. Sobre vacunas. https://t.co/KbKLpID9Qf'>, <Tweet id=1552446567873150977 text='@Jim_Jordan Because they can\'t drive fear of Monkeypox  and Covid to scare people into locking down so they can roll out ,what Joe Biden called" the vast network of voter fraud"!'>, <Tweet id=1552446567642464256 text="@fedesiino @AngeloCapparel9 @evamarghe Signora, ripeto il Rapporto Debito/PIL é cresciuto durante l'anno 2019; non eravamo  in piena pandemia; i primi casi Covid accertati risalgono a fine febbraio 2020. Come dice open polis c'è stata diminuzio
# ...

# %%
for tweet in response.data:
    print(tweet.id)
    print(tweet.lang)
# Out:
# 1552446572662853632
# en
# 1552446572382027776
# en
# 1552446569047359489
# es
# 1552446567873150977
# en
# 1552446567642464256
# it
# 1552446565515935745
# en
# 1552446563838218240
# en
# 1552446562315427841
# es
# 1552446559228665856
# en
# 1552446558263820288
# en
# 1552446556204580864
# en
# 1552446554258153473
# en
# 1552446550621966336
# en
# 1552446548176519168
# en
# 1552446543885930501
# el
# 1552446540350107648
# en
# 1552446538819186688
# en
# 1552446537804185603
# pt
# 1552446535174340608
# en
# 1552446528731635712
# en
# 1552446528308248576
# en
# 1552446524046848001
# en
# 1552446521752408064
# pt
# 1552446520762531843
# en
# 1552446520246796288
# en
# 1552446517327597568
# en
# 1552446514076995584
# en
# 1552446502580404224
# en
# 1552446501351493632
# en
# 1552446499338207232
# tl
# 1552446499208200192
# en
# 1552446497823887366
# es
# 1552446496066670593
# en
# 1552446494955151360
# en
# 1552446494434893827
# en
# 1552446494304780291
# en
# 1552446494091145216
# en
# ...

# %%
response = client.search_recent_tweets(query = query, max_results = 100, tweet_fields = ['created_at', 'lang'], expansions= ['author_id'])

users = {u['id'] : u for u in response.includes['users']}

for tweet in response.data:
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        
    print(tweet.text)
    print(user.username)
# Out:
# Joe Biden didn't have Covid 19! After his big F.U.C.K UP trip to Israel, Saudi Arabia, etc &amp; looking like a complete loser &amp; idiot to the whole world. The Dems wanted to hide Joe Biden from us, Citizens for 2 wks, before he screw up again!
# Rosemar48893330
# @JoyceS763 And again. Can do this all day.
#
# https://t.co/U0hM9efkz0
# pham56
# COVID-19. Sobre vacunas. https://t.co/KbKLpID9Qf
# DemiurgoTuiter
# @Jim_Jordan Because they can't drive fear of Monkeypox  and Covid to scare people into locking down so they can roll out ,what Joe Biden called" the vast network of voter fraud"!
# ingoals20
# @fedesiino @AngeloCapparel9 @evamarghe Signora, ripeto il Rapporto Debito/PIL é cresciuto durante l'anno 2019; non eravamo  in piena pandemia; i primi casi Covid accertati risalgono a fine febbraio 2020. Come dice open polis c'è stata diminuzione durante il 2020 fino a fine 2021. Quale sia la situazione ora non lo so. https://t.co/oWqunBD3Fl
# PaoloStanzani2
# ...

# %%
response = client.search_recent_tweets(query = query, max_results = 100, tweet_fields = ['created_at', 'lang'], expansions= ['author_id'], user_fields=['profile_image_url'] )

users = {u['id'] : u for u in response.includes['users']}

for tweet in response.data:
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        
    print(tweet.text)
    print(user.profile_image_url)
# Out:
# @TPostMillennial Tucker was vaccinated for Covid as per Fox’ rules
# https://pbs.twimg.com/profile_images/1479285227767812096/XKo-gdpo_normal.jpg
# How I felt talking to Devin from my window tonight. #COVID https://t.co/nfcGsXTjHS
# https://pbs.twimg.com/profile_images/1292685422020235264/2iubA_-o_normal.jpg
# Joe Biden didn't have Covid 19! After his big F.U.C.K UP trip to Israel, Saudi Arabia, etc &amp; looking like a complete loser &amp; idiot to the whole world. The Dems wanted to hide Joe Biden from us, Citizens for 2 wks, before he screw up again!
# https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
# @JoyceS763 And again. Can do this all day.
#
# https://t.co/U0hM9efkz0
# https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
# COVID-19. Sobre vacunas. https://t.co/KbKLpID9Qf
# https://pbs.twimg.com/profile_images/892325678972096512/g9DdSsjt_normal.jpg
# ...

# %%
# More than 100 tweets

for tweet in tweepy.Paginator(client.search_recent_tweets, query = query, max_results = 100).flatten(limit = 1000):
    print(tweet.id)
# Out:
# 1552446577461334016
# 1552446574688878592
# 1552446572662853632
# 1552446572382027776
# 1552446569047359489
# 1552446567873150977
# 1552446567642464256
# 1552446565515935745
# 1552446563838218240
# 1552446562315427841
# 1552446559228665856
# 1552446558263820288
# 1552446556204580864
# 1552446554258153473
# 1552446550621966336
# 1552446548176519168
# 1552446543885930501
# 1552446540350107648
# 1552446538819186688
# 1552446537804185603
# 1552446535174340608
# 1552446528731635712
# 1552446528308248576
# 1552446524046848001
# 1552446521752408064
# 1552446520762531843
# 1552446520246796288
# 1552446517327597568
# 1552446514076995584
# 1552446502580404224
# 1552446501351493632
# 1552446499338207232
# 1552446499208200192
# 1552446497823887366
# 1552446496066670593
# 1552446494955151360
# 1552446494434893827
# 1552446494304780291
# 1552446494091145216
# 1552446487606460418
# 1552446484897202176
# 1552446483009617920
# 1552446482263216128
# 1552446478114766850
# 1552446474088488963
# ...

# %%
filename = "tweets.txt"

with open(filename, 'a+') as filehandler:
    for tweet in tweepy.Paginator(client.search_recent_tweets, query = query, max_results = 100).flatten(limit = 1000):
        filehandler.write('%s\n' % tweet.id)

# %%
#Get users timeline
users = client.get_users(usernames = ['twitterdev'])

for user in users:
    print(user)
# Out:
# [<User id=2244994945 name=Twitter Dev username=TwitterDev>]
# {}
# []
# {}

# %%
tweets = client.get_users_tweets(id = user_id, tweet_fields= ['lang'])

# %%
for tweet in tweets.data:
    print(tweet.id)
    print(tweet.lang)
    print(tweet.text)
# Out:
# 1552428626380980226
# en
# NoPurchNec. Open to teams and individuals in permitted countries who are legal adults. Entry Period: June 21-August 19, 2022.  Sponsor: Twitter, Inc. Admin: DevPost, Inc.
# 1552428624493641729
# en
# Want to make Twitter better for everyone and win prizes doing it? 💰
#
# Join the #ChirpDevChallenge, open now until August 19th, for a chance to win cash prizes, promotion, and major bragging rights. 🏆
#
# Enter the challenge here ⬇️
# https://t.co/uxAOPqtq3v https://t.co/cQa8smtDAt
# 1552368228223041537
# en
# We launched our team profile in partnership with @Replit. Try out the new functionality of the Twitter API v2 without writing a code, and get started easily and quickly with our templates. ✨
#
# https://t.co/0CWY1bMKZB https://t.co/TAm5s5RXID
# 1552358227354030082
# en
# ...

# %%
tweets = client.get_users_mentions(id = user_id, tweet_fields= ['lang'])
for tweet in tweets.data:
    print(tweet.id)
    print(tweet.lang)
    print(tweet.text)
# Out:
# 1552440772150304768
# en
# @ArkJenB @TwitterDev Bruhhhhh https://t.co/BkoCI6JzJo
# 1552427845934321665
# und
# @AndrewVoirol @TwitterDev @lyongreg @andypiper :) https://t.co/hndiYYmDGr
# 1552426763946434560
# en
# Dear @TwitterSpaces, Please host a "Town Hall" Space about Twitter Spaces UI / UX / features just like this, there's a lot of people and a lot of feedback
#
# Right now they're all leaking into @TwitterDev API Spaces 🤣
#
# The People demand an audience! @c_at_work @lyongreg @smartfuse https://t.co/zf6GP83eHH
# 1552426178736185349
# en
# @TwitterDev @lyongreg @andypiper Heavily binging ‘Peaky Blinders’ while recovering from a health thing and hearing @andypiper and @_andrewlyons, I almost wanted to raise my hand and say “By Order of the Peaky Foookin’ Blinders, would you PLEASE, keep your questions on topic!”
#
# I applaud your patience &amp; grace. https://t.co/I2AfUHicjj
# 1552425397119504384
# en
# ...

# %%
users = client.get_users_followers( id = user_id)

for user in users.data:
    print(user)
# Out:
# kingTek15
# syscrprt
# MiracleJe50
# maliikawalker
# ariefovic
# ZSHAIK19
# amusulan
# MunemHashmi
# Ohunene00
# hcankahraman
# pukthuanthongk
# VizB0t
# hampton_amia
# updatary
# KarrieRoss
# OpenVirtualSTEM
# Illiana_Zerihun
# iambenmathias
# gregscloud1
# Nuraahnora12345
# Mox_Phi11ip
# JustDani2020
# TyreeLHolland
# WarrenGzMaps
# Allspires
# misterg3234
# GullahRehabbed
# SheTalksFootbal
# AndreGarca
# JoaoNewman
# jdotalan
# JoeMangrum
# soda153
# dakus_jocelyn
# AgentSmith829
# alazsengul
# JoeMayo
# Rhon23985453
# rahoi
# elisaveta_lyons
# naujinot
# mdevx
# citizenmfitzp
# NKelleherAuthor
# haenity
# nullmetry
# BadgerNoble
# FDeitelhoff
# PeeTeeEssDee
# KinoPalmer
# siva_twi
# BethFrost5
# cbyrne321
# IvanCoding
# barnett_tracy
# anhtt19
# cze_mb
# joshuazobule
# hyouies
# ImShivraj__
# NaremeH
# OmaleOJohnpaul
# Drtuber_com
# stianlagstad
# MoisesricoRico
# yigitertem
# not_anth
# ___Nadaaa
# Adrienn62025259
# NFTJAY44
# mbhajantri
# Nyoka_Chatu
# the_urban_fight
# ...

# %%
users = client.get_users_following( id = user_id)

for user in users.data:
    print(user)
# Out:
# elonmusk
# 2006legend
# jessicagarson
# bitcoincoreorg
# Punkaboo
# coraF256
# ashevat
# TheSherylKlein
# mongeliliana
# JulieMendoza206
# rahul_pushkarna
# jason_in_japan
# jenkpowers
# Si_ximujin
# FindingMeeemo
# jpodnos
# HoranMikeS
# ericmartinyc
# haimvat
# briankahrs
# vincethecoder
# HackerScorer
# sunscreenpapi
# khammami
# miss_mixtape
# imaria20_
# twum_jnr
# Sprinklr
# ryanjgallag
# JohnSpall247
# selynnasun
# RainaMerchant
# SyasCode
# nahidofficialbd
# mjzitek
# JaimeOtraVez
# Antoinedroid
# Mistermatt007
# PennMedCDH
# roycehaynes
# deevirga
# KellyAyo
# JamesLoduca
# Derella
# RebeccaW
# ChelseaHipwood
# andyantos
# _mirels_
# arisirenita
# mauropiano
# anniehanannie
# mattjbones
# artxbel
# farez
# thedavecarroll
# Sr__Half
# vice_elisabete
# _luisf02
# GibbyBlogger
# Sanji4579094169
# evanholt
# not_stin
# Chopra_Shagun
# tianz_zzz
# bolaboss
# WoojuGG
# replylord
# laur_tray
# AmberAlBrown
# kdspaul
# twitpane
# duraidabdul
# ramiro__nd
# amyleebenn
# NiklasBuelow
# ...

# %%
Tweet_ID = '1552123431990304768'

# %%
users = client.get_liking_users(id = Tweet_ID)

for user in users.data:
    print(user.username)
# Out:
# Wandary6
# allan__millan
# juliorolandoovi
# KevinAl28458644
# Zamora_Car98
# BranKazama21
# JuanC02299945
# HectorRapaloC28
# cesar49658605
# FredyRam96
# dean47dean
# eg_manolo
# JesusGa72401395
# toni_crow
# 0glaOgla79
# hectortitor09
# kikejimenezlara
# prodrin
# FisgnMorboson2
# 1995CyK
# jemilioga
# Gabrielrm_11
# caen9
# Elnon34757841
# iangutierrez_7
# KevinJessGarca2
# CarlosM91345726
# Emmanue33859650
# AnnoticiasApatz
# ivancillo80
# profeElmerGT
# Padilla121
# JulioCs33834594
# DiegoRo94453457
# Tavo19881
# SaulGme69738068
# elbarton27
# f_ernando10
# Bryandh13
# Enz_mike28
# JoseGut24653103
# Dario14750
# donald_florez
# DiegoVGtz
# renerangel
# cafr3y
# fahm301074
# braavitoo
# geraubesa
# sephardy
# ethelberto90
# Die90546108
# gerardo75983178
# Estebandido2127
# Rubenz25060802
# rpolitoantele
# danielboy293
# LuisEnr91268764
# juanfer_gaturro
# M83177
# mai31196
# orlandoacmilan
# graciela5701
# luisAdo44031261
# LuisMan53767592
# AdrianLopezRe12
# brady325
# ...

# %%
users = client.get_retweeters(id=Tweet_ID)

for user in users.data:
    print(user.id)
# Out:
# 203369537
# 733969377775616000
# 267037873
# 1522051879613583366
# 75544363
# 4396086143
# 1427680088204611584
# 854808037143523328
# 224534138
# 190446106
# 41487203
# 1497318305685716992
# 232712333
# 1327454150854991872
# 1048024112537489408
# 1256620023461756928
# 138535419
# 1297389388314431488
# 1292330659491586049
# 2149827504
# 818521188632788992
# 1423118779995856896
# 385014516
# 40052231
# 1513600611668922374
# 305004737
# 4808112787
# 1298643558996611072
# 82588474
# 264501145
# 1162779483256053761
# 1429530540999282688
# 1435668126675386368
# 1538215552052764673
# 183662812
# 1267458042330824705
# 104401686
# 344402111
# 335540675
# 760344457640161280
# 605919031
# 3804443773
# 202032037
# 1495063359753965568
# 1050640427362091011
# 1423004164167241731
# 2947155717
# 1035953065
# 485976186
# 1522325285177282560
# 706259052334968832
# 2526499440
# 993609081343668224
# 1547936664340664321
# 1425885312706826247
# 871172471755423744
# 1486820273315889157
# 152367707
# ...

# %%
response = client.get_tweet(id=Tweet_ID)
response
# Out:
# Response(data=<Tweet id=1552123431990304768 text='Los americanistas, por las nubes…'>, includes={}, errors=[], meta={})

# %%
#CREATING

# %%
client = tweepy.Client(consumer_key = API_Key, 
                      consumer_secret = API_Key_Secret, 
                      access_token = Access_Token,
                      access_token_secret = Access_Token_Secret)

# %%
response = client.create_tweet(text = 'Hello World!')
print(response)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 response = client.create_tweet(text = 'Hello World!')
#       2 print(response)
#
# File /opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:824, in Client.create_tweet(self, direct_message_deep_link, for_super_followers_only, place_id, media_ids, media_tagged_user_ids, poll_duration_minutes, poll_options, quote_tweet_id, exclude_reply_user_ids, in_reply_to_tweet_id, reply_settings, text, user_auth)
#     821 if text is not None:
#     822     json["text"] = text
# --> 824 return self._make_request(
#     825     "POST", f"/2/tweets", json=json, user_auth=user_auth
#     826 )
#
# File /opt/anaconda3/lib/python3.9/site-packages/tweepy/client.py:126, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
# ...

# %%
response = client.create_tweet(text = 'Hello World! Here we have a poll', poll_duration_minutes = 10, poll_options = ['yes', 'no'])
print(response)

# %%
response = client.retweet(tweet_id = Tweet_ID)
response

# %%
response = client.create_tweet(in_reply_to_tweet_id = '1552441376058621953', text = 'Hello')
response

# %%
for tweet in tweepy.Paginator(client.create_tweet, text = 'Hello @MVROM, this is a bot').flatten(limit = 10):
    print(tweet)

# %%
i = 0
while (i < 10):
    i = i + 1
    print(i)

# %%
i = 0
while (i < 10):
    
    response = client.create_tweet(text = 'Hello @MVROM, this is coming from a bot'+ str(i) +', do not be afraid')
    print(response)
    i = i + 1

# %%
tweet_ids = []
client_query = tweepy.Client(bearer_token = Bearer_Token)
users = client_query.get_users(usernames = ['MVROM'])
user_id = '123'
for user in users.data:
    
    user_id = user.id
    
print(user_id)
# Out:
# 91221768

# %%
tweets_MVROM = client_query.get_users_tweets(id = user_id, tweet_fields= ['lang'])
for tweet in tweets_MVROM.data:
    print(tweet.text)
# Out:
# When everything else fails me… music doesn't.
# Thank God for Audioslave.
# I've been freed of this emotional burden.
# If you only knew the plans they have for us…
# La vida reside dentro de la locura y el caos.
# 🥴 https://t.co/fHygXe9PNf
# @jayasupertramp x2 hermano, x2.
# RT @PonchoGutz: Muéstrales que México es el país que mejor ha controlado la inflación enegética y ellos te saldrán con otros datos.
#
# Muéstr…
# @Feer_Gonzalez1 Me siento atacado. Jajaja no te creas; sí aplica también.
# Nothing's really real, no one really feels, nothing to declare.

# %%
filename = "MVROM_tweets_cleared.txt"
tweet_ids_cleared = []
with open(filename, 'a+') as filehandler:
    for tweet in tweepy.Paginator(client_query.get_users_tweets, id = user_id, max_results = 100).flatten(limit = 1500):
        filehandler.write('%s\n' % tweet.id)
        tweet_ids_cleared.append(tweet.id)

# %%
#for tw in tweet_ids:
#    response = client.like(tw)
#    print(response)

# %%
len(tweet_ids_cleared)
# Out:
# 1500

# %%
Tweets_text = []
for tweet in tweepy.Paginator(client_query.get_users_tweets, id = user_id, max_results = 100).flatten(limit = 1500):
        Tweets_text.append(tweet.text)

# %%
Tweets_text
# Out:
# ["When everything else fails me… music doesn't.",
#  'Thank God for Audioslave.',
#  "I've been freed of this emotional burden.",
#  'If you only knew the plans they have for us…',
#  'La vida reside dentro de la locura y el caos.',
#  '🥴 https://t.co/fHygXe9PNf',
#  '@jayasupertramp x2 hermano, x2.',
#  'RT @PonchoGutz: Muéstrales que México es el país que mejor ha controlado la inflación enegética y ellos te saldrán con otros datos.\n\nMuéstr…',
#  '@Feer_Gonzalez1 Me siento atacado. Jajaja no te creas; sí aplica también.',
#  "Nothing's really real, no one really feels, nothing to declare.",
#  'Es más factible que Cyberpunk 2077 se lleve a cabo en Baja California que en California.',
#  '- Tener un Tesla\n- Orientación sexual\n- Hacer trading en Cripto https://t.co/DWYSOdn7n9',
#  "@alexavrom It's from young T.",
#  "I'd give up my bakery to have a piece of your pie.",
#  'The Best Thing (2009).',
#  'Pasar de un punto a otro. Trascender.',
# ...

# %%
df = pd.DataFrame()

# %%
df['ID'] = tweet_ids_cleared

# %%
df['Tweet'] = Tweets_text

# %%
df.head()
# Out:
#                     ID                                          Tweet
# 0  1551361273232769024  When everything else fails me… music doesn't.
# 1  1551360293661450242                      Thank God for Audioslave.
# 2  1550647629029093376      I've been freed of this emotional burden.
# 3  1550259934868037632   If you only knew the plans they have for us…
# 4  1549986163171024896  La vida reside dentro de la locura y el caos.

# %%
df = df[~df.Tweet.str.contains("RT")]
df = df.reset_index(drop = True)

# %%
df.head(50)
# Out:
#                      ID                                              Tweet
# 0   1551361273232769024      When everything else fails me… music doesn't.
# 1   1551360293661450242                          Thank God for Audioslave.
# 2   1550647629029093376          I've been freed of this emotional burden.
# 3   1550259934868037632       If you only knew the plans they have for us…
# 4   1549986163171024896      La vida reside dentro de la locura y el caos.
# 5   1549916591155884032                          🥴 https://t.co/fHygXe9PNf
# 6   1549916542032158721                    @jayasupertramp x2 hermano, x2.
# 7   1549875887201406976  @Feer_Gonzalez1 Me siento atacado. Jajaja no t...
# 8   1549863441451458560  Nothing's really real, no one really feels, no...
# 9   1549849514361495552  Es más factible que Cyberpunk 2077 se lleve a ...
# 10  1549849199285374976  - Tener un Tesla\n- Orientación sexual\n- Hace...
# ...

# %%
#This splits all the sentences up which makes it easier for us to work with

all_sentences = []
df_cleaning = df
for word in df_cleaning["Tweet"]:
    all_sentences.append(word)

all_sentences
#df1 = df.to_string()

#df_split = df1.split()

#df_split
lines = list()
for line in all_sentences:    
    words = line.split()
    for w in words: 
       lines.append(w)


print(lines)
# Out:
# ['When', 'everything', 'else', 'fails', 'me…', 'music', "doesn't.", 'Thank', 'God', 'for', 'Audioslave.', "I've", 'been', 'freed', 'of', 'this', 'emotional', 'burden.', 'If', 'you', 'only', 'knew', 'the', 'plans', 'they', 'have', 'for', 'us…', 'La', 'vida', 'reside', 'dentro', 'de', 'la', 'locura', 'y', 'el', 'caos.', '🥴', 'https://t.co/fHygXe9PNf', '@jayasupertramp', 'x2', 'hermano,', 'x2.', '@Feer_Gonzalez1', 'Me', 'siento', 'atacado.', 'Jajaja', 'no', 'te', 'creas;', 'sí', 'aplica', 'también.', "Nothing's", 'really', 'real,', 'no', 'one', 'really', 'feels,', 'nothing', 'to', 'declare.', 'Es', 'más', 'factible', 'que', 'Cyberpunk', '2077', 'se', 'lleve', 'a', 'cabo', 'en', 'Baja', 'California', 'que', 'en', 'California.', '-', 'Tener', 'un', 'Tesla', '-', 'Orientación', 'sexual', '-', 'Hacer', 'trading', 'en', 'Cripto', 'https://t.co/DWYSOdn7n9', '@alexavrom', "It's", 'from', 'young', 'T.', "I'd", 'give', 'up', 'my', 'bakery', 'to', 'have', 'a', 'piece', 'of', 'your', 'pie.', 'The'
# ...

# %%
#Removing Punctuation
import re
lines = [re.sub(r'[\W_]+', '', x) for x in lines]
##re.sub(r'[\W_]+', '', s)
lines

lines2 = []

for word in lines:
    if word != '':
        lines2.append(word)

# %%
df_final = pd.DataFrame(important_words)

df_final = df_final[0].value_counts()

# %%
from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df_final:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 2494, 2: 518, 3: 242, 4: 144, 5: 95, 6: 51, 8: 46, 7: 35, 9: 22, 10: 19, ...})

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#This is a simple plot that shows the top 20 words being used
#df.plot(20)
plt.clf()
df_plotting = df_final[:20,]
plt.figure(figsize=(10,5))
sns.barplot(df_plotting.values, df_plotting.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_plotting.head(25)
# Out:
# qu                100
# tod                89
# par                81
# ms                 71
# dannapaulinard     62
# feergonzalez1      59
# s                  58
# com                57
# sopeetah           53
# si                 52
# hac                48
# est                45
# medi               42
# cre                40
# siempr             38
# mism               38
# gent               38
# jajaj              36
# pas                35
# jayasupertramp     35
# Name: 0, dtype: int64

# %%
with open('stop_words.txt', 'r') as f:
    myNames = f.readlines()
    
    
myNames = [s.replace('\n', '') for s in myNames]

myNames

#replace('\n', '')
# Out:
# ['algún',
#  'alguna',
#  'algunas',
#  'alguno',
#  'algunos',
#  'ambos',
#  'ampleamos',
#  'ante',
#  'antes',
#  'aquel',
#  'aquellas',
#  'aquellos',
#  'aqui',
#  'arriba',
#  'atras',
#  'bajo',
#  'bastante',
#  'bien',
#  'cada',
#  'cierta',
#  'ciertas',
#  'cierto',
#  'ciertos',
#  'como',
#  'con',
#  'conseguimos',
#  'conseguir',
#  'consigo',
#  'consigue',
#  'consiguen',
#  'consigues',
#  'cual',
#  'cuando',
#  'dentro',
#  'desde',
#  'donde',
#  'dos',
#  'el',
#  'ellas',
#  'ellos',
#  'empleais',
#  'emplean',
#  'emplear',
#  'empleas',
#  'empleo',
#  'en',
#  'encima',
#  'entonces',
#  'entre',
#  'era',
#  'eramos',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esta',
#  'estaba',
#  'estado',
#  'estais',
#  'estamos',
#  'estan',
#  'estoy',
#  'fin',
#  'fue',
#  'fueron',
#  'fui',
#  'fuimos',
#  'gueno',
#  'ha',
#  'hace',
#  'haceis',
#  'hacemos',
#  'hacen',
#  'hacer',
#  'haces',
#  'hago',
#  'incluso',
#  'intenta',
#  'intentais',
# ...

# %%
newdata = df

pat = '|'.join(r"\b{}\b".format(x) for x in myNames)
newdata['Tweet 1'] = newdata['Tweet'].str.replace(pat, '')


top_words = set(stop_words)
f = lambda x: ' '.join(w for w in x.split() if not w in myNames)
newdata['Tweet 2'] = newdata['Tweet'].apply(f)

print (newdata)
# Out:
#                        ID                                              Tweet  \
# 0     1551361273232769024      When everything else fails me… music doesn't.
# 1     1551360293661450242                          Thank God for Audioslave.
# 2     1550647629029093376          I've been freed of this emotional burden.
# 3     1550259934868037632       If you only knew the plans they have for us…
# 4     1549986163171024896      La vida reside dentro de la locura y el caos.
# ...                   ...                                                ...
# 1281  1273996812278325249  @dannapaulinard Igual hay maneras de sobrellev...
# 1282  1273962990149103616            @dannapaulinard https://t.co/xWQuF91w3J
# 1283  1273817074532376576            @alexavrom Alineación y balanceo xdxdxd
# 1284  1273816813910945792                          @sofiaarcew Y no invitas.
# 1285  1273653769855778817         @LewisHamilton Plant-based power ftw, bro.
#
# ...

# %%
#This splits all the sentences up which makes it easier for us to work with

all_sentences = []

for word in newdata["Tweet 2"]:
    all_sentences.append(word)

all_sentences
#df1 = df.to_string()

#df_split = df1.split()

#df_split
lines = list()
for line in all_sentences:    
    words = line.split()
    for w in words: 
       lines.append(w)


print(lines)
# Out:
# ['When', 'everything', 'else', 'fails', 'me…', 'music', "doesn't.", 'Thank', 'God', 'for', 'Audioslave.', "I've", 'been', 'freed', 'of', 'this', 'emotional', 'burden.', 'If', 'you', 'only', 'knew', 'the', 'plans', 'they', 'have', 'for', 'us…', 'La', 'vida', 'reside', 'locura', 'caos.', '🥴', 'https://t.co/fHygXe9PNf', '@jayasupertramp', 'x2', 'hermano,', 'x2.', '@Feer_Gonzalez1', 'Me', 'siento', 'atacado.', 'Jajaja', 'te', 'creas;', 'aplica', 'también.', "Nothing's", 'really', 'real,', 'one', 'really', 'feels,', 'nothing', 'to', 'declare.', 'Es', 'factible', 'Cyberpunk', '2077', 'lleve', 'cabo', 'Baja', 'California', 'California.', '-', 'Tener', 'Tesla', '-', 'Orientación', 'sexual', '-', 'Hacer', 'trading', 'Cripto', 'https://t.co/DWYSOdn7n9', '@alexavrom', "It's", 'from', 'young', 'T.', "I'd", 'give', 'up', 'my', 'bakery', 'to', 'have', 'piece', 'of', 'your', 'pie.', 'The', 'Best', 'Thing', '(2009).', 'Pasar', 'punto', 'otro.', 'Trascender.', 'I', 'think', "I'm", 'old', 'enough', 't
# ...

# %%
df5 = pd.DataFrame(lines)

df5 = df5[0].value_counts()

# %%
from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df5:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 4848, 2: 691, 3: 235, 4: 111, 5: 83, 6: 53, 7: 30, 8: 24, 9: 18, 10: 11, ...})

# %%
#This is a simple plot that shows the top 20 words being used
#df.plot(20)
plt.clf()
df6 = df5[:50,]
plt.figure(figsize=(10,15))
sns.barplot(df6.values, df6.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Removing all Stop Words
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import re  
import spacy
nlp = spacy.load('en_core_web_sm')
stem2 = []

for word in lines:
    if word not in nlp.Defaults.stop_words:
        stem2.append(word)

#stem2
stem2
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/fernandohuerta/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/fernandohuerta/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fernandohuerta/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['When',
#  'fails',
#  'me…',
#  'music',
#  "doesn't.",
#  'Thank',
#  'God',
#  'Audioslave.',
#  "I've",
#  'freed',
#  'emotional',
#  'burden.',
#  'If',
#  'knew',
#  'plans',
#  'us…',
#  'La',
#  'vida',
#  'reside',
#  'locura',
#  'caos.',
#  '🥴',
#  'https://t.co/fHygXe9PNf',
#  '@jayasupertramp',
#  'x2',
#  'hermano,',
#  'x2.',
#  '@Feer_Gonzalez1',
#  'Me',
#  'siento',
#  'atacado.',
#  'Jajaja',
#  'te',
#  'creas;',
#  'aplica',
#  'también.',
#  "Nothing's",
#  'real,',
#  'feels,',
#  'declare.',
#  'Es',
# ...

# %%
df = pd.DataFrame(stem2)

df = df[0].value_counts()

# %%
from nltk.probability import FreqDist

freqdoctor = FreqDist()

for words in df:
    freqdoctor[words] += 1

freqdoctor
# Out:
# FreqDist({1: 4807, 2: 663, 3: 217, 4: 105, 5: 73, 6: 49, 7: 20, 8: 19, 9: 10, 10: 7, ...})

# %%
plt.clf()
df = df[:30,]
plt.figure(figsize=(10,8))
sns.barplot(df.values, df.index, alpha=0.8)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
